# %%
import sys
sys.path.append('/home/ardelalegre/SoundMapping/Analysis/Util')
from get_time_interval_matrix_data import get_time_interval_matrix_data
from PCA import get_cdata
from PCA import project_to_eigen_vectors
from Plot import plot_data

data = get_time_interval_matrix_data('Sep 28 2020 10:00AM', 'Sep 28 2020 04:50PM')
cdata = get_cdata(data[:, 1:])
projected_data = project_to_eigen_vectors(cdata, 2)
plot_data(projected_data)
# Out:
# /home/ardelalegre/SoundMapping/Analysis/Util/PCA.py:44: RuntimeWarning: Mean of empty slice
#   data_mean = np.nanmean(data,axis = 0,keepdims = True)

# %%
plot_data(projected_data)

# %%
import sys
sys.path.append('/home/ardelalegre/SoundMapping/Analysis/Util')
from get_time_interval_matrix_data import get_time_interval_matrix_data

data = get_time_interval_matrix_data('Sep 28 2020 10:00AM', 'Sep 28 2020 04:50PM')

# %%
from get_eigen_vectors import get_eigen_vectors

values, vectors = get_eigen_vectors(data[:, 1:])
# Out:
# /home/ardelalegre/SoundMapping/Analysis/Util/get_eigen_vectors.py:13: RuntimeWarning: Mean of empty slice
#   data_mean = np.nanmean(data,axis = 0,keepdims = True)

# %%
values
# Out:
# array([0.11643512, 0.06973232, 0.06414829, 0.05811179, 0.05008431,
#        0.04354229, 0.01247356, 0.03666576, 0.03193203, 0.01598887,
#        0.0179332 , 0.02827345, 0.02493487, 0.0216032 , 0.02269648,
#        0.        , 0.        , 0.        ])

# %%
vectors
# Out:
# array([[-5.58767736e-02,  1.62917742e-01, -6.14916360e-02,
#          5.95497004e-02,  1.30366390e-01,  3.07711513e-02,
#          9.49480861e-01,  2.61951998e-02, -4.72443414e-02,
#         -1.42676820e-01,  5.26842567e-02, -8.62183737e-02,
#          5.18067375e-02,  8.51525395e-02,  1.15333635e-02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 4.30837996e-01, -3.62281942e-01,  7.21579731e-02,
#         -3.53786592e-01, -4.22010358e-01, -4.39277553e-03,
#          1.57999909e-01,  1.25305142e-01,  1.08400426e-01,
#         -1.92185899e-01, -4.64822554e-01,  1.20128015e-02,
#         -8.57618923e-02,  2.26602033e-01, -1.01918261e-01,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-2.86914334e-01,  3.09984945e-01, -5.37820740e-02,
#          2.70209975e-01,  2.50976716e-01,  3.14470554e-02,
#         -1.40307424e-01,  7.03901168e-02,  3.78869520e-02,
#         -2.82347894e-01, -6.82458904e-01,  1.25748812e-01,
# ...
